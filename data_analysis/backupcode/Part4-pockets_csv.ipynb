# %%
#HER ŞEYİ CSV'YE YAZDIRMA #HER ŞEYİ CSV'YE YAZDIRMA #HER ŞEYİ CSV'YE YAZDIRMA #HER ŞEYİ CSV'YE YAZDIRMA 

import os
import glob
import csv
import pandas as pd
import seaborn as sns
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
import numpy as np

from scipy.spatial.distance import cdist
from config import processed_dir, xtc_file, pdb_dir, p2rank_processed_dir
from config import pdb_list

# Open CSV file for writing
csv_filename = os.path.join(processed_dir, "pockets.csv")
with open(csv_filename, "w", newline="") as csvfile:
    csvwriter = csv.writer(csvfile)

    # Write header
    csvwriter.writerow(["File name",'Frame', "pocket_index", "probability","residues"])

    for pdb_file in pdb_list:
        predictions_file = os.path.join(processed_dir, 'p2rank_output', os.path.basename(pdb_file).replace('.pdb', '.pdb_predictions.csv'))
        residues_file = os.path.join(processed_dir, 'p2rank_output', os.path.basename(pdb_file).replace('.pdb', '.pdb_residues.csv'))
        #print(predictions_file,residues_file)
        # Check if predictions_file exists
        if not os.path.exists(predictions_file):
            continue

        # Open predictions CSV file
        with open(predictions_file, 'r') as pred_file:
            reader = csv.DictReader(pred_file)
            #print("check")
            for row in reader:
                # Check if probability is higher than 0.5
                if float(row[' probability']) > 0.3:
                    print("check")
                    pocket_index = row['  rank']  # Pocket index
                    full_name = os.path.basename(pdb_file)[:-4]  # Get the PDB file name as the Frame attribute
                    prot_name = os.path.basename(xtc_file)[:-4]
                    frame_name = full_name.replace(prot_name,"")
                    frame_name = frame_name[1:]
                    probability = row[' probability']
                    residues = row[' residue_ids']
                    print(f"probability:{probability},residues:{residues}")
                    #print("PROTLANBU",prot_name,full_name,frame_name)
                    # Write data to the CSV file
                    csvwriter.writerow([full_name,frame_name, pocket_index, probability,residues])
                    
#print(predictions_file)


# Sort the CSV file by frame_name as integers
with open(csv_filename, 'r') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    sorted_rows = sorted(csv_reader, key=lambda x: int(x['Frame']))

# Rewrite the CSV file with sorted rows
with open(csv_filename, 'w', newline='') as csvfile:
    fieldnames = ["File name",'Frame', 'pocket_index', 'probability', 'residues']
    csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    csv_writer.writeheader()
    for row in sorted_rows:
        csv_writer.writerow(row)

#print("CSV file sorted and saved.")
# Out:
# check
# probability:       0.389,residues: A_1059 A_1060 A_1061 A_1062 A_1063 A_1122 A_1123 A_1124 A_1125 A_1126 A_1127 A_1128 A_1129 A_1130 A_1131 A_1199 A_1200 A_1201 A_1202 A_1255 A_1256 A_1257 A_1259 A_1260
# check
# probability:       0.351,residues: A_1060 A_1061 A_1062 A_1063 A_1064 A_1122 A_1123 A_1124 A_1125 A_1126 A_1129 A_1130 A_1131 A_1132 A_1199 A_1200 A_1201 A_1202 A_1203 A_1207 A_1255 A_1256 A_1257 A_1259 A_1260 A_1263 A_1264
# check
# probability:       0.331,residues: A_1060 A_1061 A_1062 A_1063 A_1064 A_1122 A_1123 A_1124 A_1125 A_1126 A_1130 A_1199 A_1200 A_1201 A_1202 A_1255 A_1256 A_1257 A_1258 A_1259 A_1260 A_1261
# check
# probability:       0.449,residues: A_1073 A_1076 A_1078 A_1080 A_1109 A_1110 A_1111 A_1112 A_1115 A_1116 A_1134 A_1135 A_1136 A_1137 A_1138 A_1144 A_1168 A_1171 A_1172 A_1174 A_1175 A_1182 A_1183 A_1184 A_1185 A_1186 A_1194 A_1195 A_1196
# check
# probability:       0.311,residues: A_1060 A_1061 A_1062 A_1063 A_1064 A_1122 A_1123 A_1124 A_1125 A_1126 A_1128 A_1130 A_1131 A_1150 A_1199 A_1200 A_1201 A_1202 A_1256 A_1257 A_1258 A_1259 A_1260 A_1261 A_1263 A_1264
# check
# probability:       0.302,residues: A_1060 A_1061 A_1063 A_1122 A_1123 A_1124 A_1125 A_1126 A_1127 A_1128 A_1130 A_1150 A_1199 A_1200 A_1201 A_1202 A_1255 A_1256 A_1257 A_1259 A_1260
# check
# probability:       0.333,residues: A_1060 A_1061 A_1063 A_1064 A_1122 A_1123 A_1124 A_1125 A_1126 A_1130 A_1199 A_1200 A_1201 A_1202 A_1203 A_1207 A_1255 A_1256 A_1257 A_1258 A_1259 A_1260 A_1263 A_1264
# check
# probability:       0.322,residues: A_1058 A_1059 A_1060 A_1061 A_1063 A_1122 A_1123 A_1124 A_1125 A_1126 A_1127 A_1128 A_1130 A_1199 A_1200 A_1201 A_1202 A_1255 A_1256 A_1257 A_1258 A_1259 A_1260 A_1410
# check
# probability:       0.323,residues: A_1059 A_1060 A_1061 A_1062 A_1063 A_1121 A_1122 A_1123 A_1124 A_1125 A_1130 A_1199 A_1200 A_1201 A_1202 A_1255 A_1256 A_1257 A_1259 A_1260
# check
# probability:       0.369,residues: A_1058 A_1059 A_1060 A_1061 A_1062 A_1063 A_1122 A_1123 A_1124 A_1125 A_1126 A_1128 A_1129 A_1130 A_1199 A_1200 A_1201 A_1202 A_1203 A_1253 A_1254 A_1255 A_1256 A_1257 A_1258 A_1259 A_1260
# check
# probability:       0.346,residues: A_1058 A_1059 A_1060 A_1061 A_1063 A_1064 A_1121 A_1122 A_1123 A_1124 A_1125 A_1126 A_1130 A_1132 A_1148 A_1199 A_1200 A_1201 A_1202 A_1255 A_1256 A_1257 A_1258 A_1259 A_1260 A_1261 A_1263
# check
# probability:       0.347,residues: A_1073 A_1074 A_1075 A_1076 A_1078 A_1079 A_1080 A_1110 A_1111 A_1112 A_1113 A_1115 A_1116 A_1134 A_1135 A_1136 A_1137 A_1142 A_1143 A_1144 A_1147 A_1183 A_1184 A_1185 A_1186 A_1187 A_1188 A_1193 A_1195
# check
# probability:       0.346,residues: A_1059 A_1060 A_1061 A_1063 A_1064 A_1122 A_1123 A_1124 A_1125 A_1130 A_1199 A_1200 A_1201 A_1202 A_1207 A_1256 A_1257 A_1258 A_1259 A_1260 A_1261 A_1263 A_1264
# check
# probability:       0.338,residues: A_1073 A_1074 A_1075 A_1076 A_1079 A_1080 A_1110 A_1111 A_1113 A_1115 A_1116 A_1117 A_1118 A_1133 A_1134 A_1135 A_1143 A_1144 A_1147 A_1148 A_1149 A_1183 A_1184 A_1185 A_1186 A_1188 A_1193 A_1194 A_1195 A_1196
# check
# probability:       0.345,residues: A_1074 A_1075 A_1076 A_1111 A_1112 A_1113 A_1115 A_1116 A_1117 A_1118 A_1133 A_1134 A_1135 A_1136 A_1137 A_1143 A_1144 A_1147 A_1148 A_1149 A_1183 A_1184 A_1185 A_1186 A_1193 A_1194 A_1195 A_1196
# check
# probability:       0.302,residues: A_1075 A_1076 A_1109 A_1110 A_1111 A_1116 A_1134 A_1135 A_1144 A_1168 A_1171 A_1172 A_1174 A_1182 A_1183 A_1184 A_1185 A_1186 A_1194 A_1195 A_1196

# %%
import os
from config import xtc_file, pdb_list
#  # Get the PDB file name as the Frame attribute

for pdb_file in pdb_list:
    full_name = os.path.basename(pdb_file)[:-4]
    print(f"full_name:{full_name}")
    prot_name = os.path.basename(xtc_file)[:-4]
    print(f"prot_name:{prot_name}")
    frame_name = full_name.replace(prot_name,"")
    print(f"frame_name:{frame_name}")
    frame_name = frame_name[1:]
    print(f"Final frame_name:{frame_name}")
# Out:
# full_name:4FOB_backbone_2673
# prot_name:4FOB_backbone
# frame_name:_2673
# Final frame_name:2673
# full_name:4FOB_backbone_991
# prot_name:4FOB_backbone
# frame_name:_991
# Final frame_name:991
# full_name:4FOB_backbone_1989
# prot_name:4FOB_backbone
# frame_name:_1989
# Final frame_name:1989
# full_name:4FOB_backbone_1345
# prot_name:4FOB_backbone
# frame_name:_1345
# Final frame_name:1345
# full_name:4FOB_backbone_2063
# prot_name:4FOB_backbone
# frame_name:_2063
# Final frame_name:2063
# full_name:4FOB_backbone_1791
# prot_name:4FOB_backbone
# frame_name:_1791
# Final frame_name:1791
# full_name:4FOB_backbone_985
# prot_name:4FOB_backbone
# frame_name:_985
# Final frame_name:985
# full_name:4FOB_backbone_675
# prot_name:4FOB_backbone
# frame_name:_675
# Final frame_name:675
# full_name:4FOB_backbone_1772
# prot_name:4FOB_backbone
# frame_name:_1772
# Final frame_name:1772
# full_name:4FOB_backbone_2477
# prot_name:4FOB_backbone
# frame_name:_2477
# Final frame_name:2477
# full_name:4FOB_backbone_1928
# prot_name:4FOB_backbone
# frame_name:_1928
# Final frame_name:1928
# full_name:4FOB_backbone_2372
# prot_name:4FOB_backbone
# frame_name:_2372
# Final frame_name:2372
# full_name:4FOB_backbone_844
# prot_name:4FOB_backbone
# frame_name:_844
# Final frame_name:844
# full_name:4FOB_backbone_1879
# prot_name:4FOB_backbone
# frame_name:_1879
# Final frame_name:1879
# full_name:4FOB_backbone_1403
# prot_name:4FOB_backbone
# frame_name:_1403
# Final frame_name:1403
# full_name:4FOB_backbone_1410
# prot_name:4FOB_backbone
# frame_name:_1410
# Final frame_name:1410
# full_name:4FOB_backbone_779
# prot_name:4FOB_backbone
# frame_name:_779
# Final frame_name:779
# full_name:4FOB_backbone_713
# prot_name:4FOB_backbone
# frame_name:_713
# Final frame_name:713
# full_name:4FOB_backbone_1689
# prot_name:4FOB_backbone
# frame_name:_1689
# Final frame_name:1689
# full_name:4FOB_backbone_2586
# prot_name:4FOB_backbone
# frame_name:_2586
# Final frame_name:2586
# full_name:4FOB_backbone_2392
# prot_name:4FOB_backbone
# frame_name:_2392
# Final frame_name:2392
# full_name:4FOB_backbone_2520
# prot_name:4FOB_backbone
# frame_name:_2520
# Final frame_name:2520
# full_name:4FOB_backbone_1427
# prot_name:4FOB_backbone
# frame_name:_1427
# Final frame_name:1427
# full_name:4FOB_backbone_1227
# prot_name:4FOB_backbone
# frame_name:_1227
# Final frame_name:1227
# full_name:4FOB_backbone_460
# prot_name:4FOB_backbone
# frame_name:_460
# Final frame_name:460
# full_name:4FOB_backbone_2036
# prot_name:4FOB_backbone
# frame_name:_2036
# Final frame_name:2036
# full_name:4FOB_backbone_648
# prot_name:4FOB_backbone
# frame_name:_648
# Final frame_name:648
# full_name:4FOB_backbone_2013
# prot_name:4FOB_backbone
# frame_name:_2013
# Final frame_name:2013
# full_name:4FOB_backbone_1731
# prot_name:4FOB_backbone
# frame_name:_1731
# Final frame_name:1731
# full_name:4FOB_backbone_2534
# prot_name:4FOB_backbone
# frame_name:_2534
# Final frame_name:2534
# full_name:4FOB_backbone_1691
# prot_name:4FOB_backbone
# frame_name:_1691
# Final frame_name:1691
# full_name:4FOB_backbone_525
# prot_name:4FOB_backbone
# frame_name:_525
# Final frame_name:525
# full_name:4FOB_backbone_1104
# prot_name:4FOB_backbone
# frame_name:_1104
# Final frame_name:1104
# full_name:4FOB_backbone_91
# prot_name:4FOB_backbone
# frame_name:_91
# Final frame_name:91
# full_name:4FOB_backbone_1759
# prot_name:4FOB_backbone
# frame_name:_1759
# Final frame_name:1759
# full_name:4FOB_backbone_408
# prot_name:4FOB_backbone
# frame_name:_408
# Final frame_name:408
# full_name:4FOB_backbone_1299
# prot_name:4FOB_backbone
# frame_name:_1299
# Final frame_name:1299
# full_name:4FOB_backbone_183
# prot_name:4FOB_backbone
# frame_name:_183
# Final frame_name:183
# full_name:4FOB_backbone_1081
# prot_name:4FOB_backbone
# frame_name:_1081
# Final frame_name:1081
# full_name:4FOB_backbone_1218
# prot_name:4FOB_backbone
# frame_name:_1218
# Final frame_name:1218
# full_name:4FOB_backbone_2716
# prot_name:4FOB_backbone
# frame_name:_2716
# Final frame_name:2716
# full_name:4FOB_backbone_236
# prot_name:4FOB_backbone
# frame_name:_236
# Final frame_name:236
# full_name:4FOB_backbone_552
# prot_name:4FOB_backbone
# frame_name:_552
# Final frame_name:552
# full_name:4FOB_backbone_2478
# prot_name:4FOB_backbone
# frame_name:_2478
# Final frame_name:2478
# full_name:4FOB_backbone_2684
# prot_name:4FOB_backbone
# frame_name:_2684
# Final frame_name:2684
# full_name:4FOB_backbone_896
# prot_name:4FOB_backbone
# frame_name:_896
# Final frame_name:896
# full_name:4FOB_backbone_1862
# prot_name:4FOB_backbone
# frame_name:_1862
# Final frame_name:1862
# full_name:4FOB_backbone_148
# prot_name:4FOB_backbone
# frame_name:_148
# Final frame_name:148
# full_name:4FOB_backbone_1774
# prot_name:4FOB_backbone
# frame_name:_1774
# Final frame_name:1774
# full_name:4FOB_backbone_976
# prot_name:4FOB_backbone
# frame_name:_976
# Final frame_name:976
# full_name:4FOB_backbone_1751
# prot_name:4FOB_backbone
# frame_name:_1751
# Final frame_name:1751
# full_name:4FOB_backbone_1477
# prot_name:4FOB_backbone
# frame_name:_1477
# Final frame_name:1477
# full_name:4FOB_backbone_860
# prot_name:4FOB_backbone
# frame_name:_860
# Final frame_name:860
# full_name:4FOB_backbone_606
# prot_name:4FOB_backbone
# frame_name:_606
# Final frame_name:606
# full_name:4FOB_backbone_1110
# prot_name:4FOB_backbone
# frame_name:_1110
# Final frame_name:1110
# full_name:4FOB_backbone_2328
# prot_name:4FOB_backbone
# frame_name:_2328
# Final frame_name:2328
# full_name:4FOB_backbone_1101
# prot_name:4FOB_backbone
# frame_name:_1101
# Final frame_name:1101
# full_name:4FOB_backbone_2109
# prot_name:4FOB_backbone
# frame_name:_2109
# Final frame_name:2109
# full_name:4FOB_backbone_1863
# prot_name:4FOB_backbone
# frame_name:_1863
# Final frame_name:1863
# full_name:4FOB_backbone_158
# prot_name:4FOB_backbone
# frame_name:_158
# Final frame_name:158
# full_name:4FOB_backbone_924
# prot_name:4FOB_backbone
# frame_name:_924
# Final frame_name:924
# full_name:4FOB_backbone_1286
# prot_name:4FOB_backbone
# frame_name:_1286
# Final frame_name:1286
# full_name:4FOB_backbone_699
# prot_name:4FOB_backbone
# frame_name:_699
# Final frame_name:699
# full_name:4FOB_backbone_1903
# prot_name:4FOB_backbone
# frame_name:_1903
# Final frame_name:1903
# full_name:4FOB_backbone_174
# prot_name:4FOB_backbone
# frame_name:_174
# Final frame_name:174
# full_name:4FOB_backbone_2609
# prot_name:4FOB_backbone
# frame_name:_2609
# Final frame_name:2609
# full_name:4FOB_backbone_692
# prot_name:4FOB_backbone
# frame_name:_692
# Final frame_name:692
# full_name:4FOB_backbone_1371
# prot_name:4FOB_backbone
# frame_name:_1371
# Final frame_name:1371
# full_name:4FOB_backbone_1877
# prot_name:4FOB_backbone
# frame_name:_1877
# Final frame_name:1877
# full_name:4FOB_backbone_1428
# prot_name:4FOB_backbone
# frame_name:_1428
# Final frame_name:1428
# full_name:4FOB_backbone_2678
# prot_name:4FOB_backbone
# frame_name:_2678
# Final frame_name:2678
# full_name:4FOB_backbone_1557
# prot_name:4FOB_backbone
# frame_name:_1557
# Final frame_name:1557
# full_name:4FOB_backbone_2479
# prot_name:4FOB_backbone
# frame_name:_2479
# Final frame_name:2479
# full_name:4FOB_backbone_1642
# prot_name:4FOB_backbone
# frame_name:_1642
# Final frame_name:1642
# full_name:4FOB_backbone_1048
# prot_name:4FOB_backbone
# frame_name:_1048
# Final frame_name:1048
# full_name:4FOB_backbone_1009
# prot_name:4FOB_backbone
# frame_name:_1009
# Final frame_name:1009
# full_name:4FOB_backbone_2290
# prot_name:4FOB_backbone
# frame_name:_2290
# Final frame_name:2290
# full_name:4FOB_backbone_2505
# prot_name:4FOB_backbone
# frame_name:_2505
# Final frame_name:2505
# full_name:4FOB_backbone_358
# prot_name:4FOB_backbone
# frame_name:_358
# Final frame_name:358
# full_name:4FOB_backbone_1298
# prot_name:4FOB_backbone
# frame_name:_1298
# Final frame_name:1298
# full_name:4FOB_backbone_2282
# prot_name:4FOB_backbone
# frame_name:_2282
# Final frame_name:2282
# full_name:4FOB_backbone_1285
# prot_name:4FOB_backbone
# frame_name:_1285
# Final frame_name:1285
# full_name:4FOB_backbone_2383
# prot_name:4FOB_backbone
# frame_name:_2383
# Final frame_name:2383
# full_name:4FOB_backbone_117
# prot_name:4FOB_backbone
# frame_name:_117
# Final frame_name:117
# full_name:4FOB_backbone_1606
# prot_name:4FOB_backbone
# frame_name:_1606
# Final frame_name:1606
# full_name:4FOB_backbone_246
# prot_name:4FOB_backbone
# frame_name:_246
# Final frame_name:246
# full_name:4FOB_backbone_360
# prot_name:4FOB_backbone
# frame_name:_360
# Final frame_name:360
# full_name:4FOB_backbone_720
# prot_name:4FOB_backbone
# frame_name:_720
# Final frame_name:720
# full_name:4FOB_backbone_590
# prot_name:4FOB_backbone
# frame_name:_590
# Final frame_name:590
# full_name:4FOB_backbone_518
# prot_name:4FOB_backbone
# frame_name:_518
# Final frame_name:518
# full_name:4FOB_backbone_1950
# prot_name:4FOB_backbone
# frame_name:_1950
# Final frame_name:1950
# full_name:4FOB_backbone_2747
# prot_name:4FOB_backbone
# frame_name:_2747
# Final frame_name:2747
# full_name:4FOB_backbone_1730
# prot_name:4FOB_backbone
# frame_name:_1730
# Final frame_name:1730
# full_name:4FOB_backbone_2458
# prot_name:4FOB_backbone
# frame_name:_2458
# Final frame_name:2458
# full_name:4FOB_backbone_1010
# prot_name:4FOB_backbone
# frame_name:_1010
# Final frame_name:1010
# full_name:4FOB_backbone_2636
# prot_name:4FOB_backbone
# frame_name:_2636
# Final frame_name:2636
# full_name:4FOB_backbone_1887
# prot_name:4FOB_backbone
# frame_name:_1887
# Final frame_name:1887
# full_name:4FOB_backbone_2718
# prot_name:4FOB_backbone
# frame_name:_2718
# Final frame_name:2718
# full_name:4FOB_backbone_1997
# prot_name:4FOB_backbone
# frame_name:_1997
# Final frame_name:1997
# full_name:4FOB_backbone_483
# prot_name:4FOB_backbone
# frame_name:_483
# Final frame_name:483
# full_name:4FOB_backbone_1625
# prot_name:4FOB_backbone
# frame_name:_1625
# Final frame_name:1625
# full_name:4FOB_backbone_1792
# prot_name:4FOB_backbone
# frame_name:_1792
# Final frame_name:1792
# full_name:4FOB_backbone_2547
# prot_name:4FOB_backbone
# frame_name:_2547
# Final frame_name:2547
# full_name:4FOB_backbone_968
# prot_name:4FOB_backbone
# frame_name:_968
# Final frame_name:968
# full_name:4FOB_backbone_2319
# prot_name:4FOB_backbone
# frame_name:_2319
# Final frame_name:2319
# full_name:4FOB_backbone_2273
# prot_name:4FOB_backbone
# frame_name:_2273
# Final frame_name:2273
# full_name:4FOB_backbone_1771
# prot_name:4FOB_backbone
# frame_name:_1771
# Final frame_name:1771
# full_name:4FOB_backbone_621
# prot_name:4FOB_backbone
# frame_name:_621
# Final frame_name:621
# full_name:4FOB_backbone_690
# prot_name:4FOB_backbone
# frame_name:_690
# Final frame_name:690
# full_name:4FOB_backbone_29
# prot_name:4FOB_backbone
# frame_name:_29
# Final frame_name:29
# full_name:4FOB_backbone_2493
# prot_name:4FOB_backbone
# frame_name:_2493
# Final frame_name:2493
# full_name:4FOB_backbone_2604
# prot_name:4FOB_backbone
# frame_name:_2604
# Final frame_name:2604
# full_name:4FOB_backbone_841
# prot_name:4FOB_backbone
# frame_name:_841
# Final frame_name:841
# full_name:4FOB_backbone_1566
# prot_name:4FOB_backbone
# frame_name:_1566
# Final frame_name:1566
# full_name:4FOB_backbone_629
# prot_name:4FOB_backbone
# frame_name:_629
# Final frame_name:629
# full_name:4FOB_backbone_270
# prot_name:4FOB_backbone
# frame_name:_270
# Final frame_name:270
# full_name:4FOB_backbone_1739
# prot_name:4FOB_backbone
# frame_name:_1739
# Final frame_name:1739
# full_name:4FOB_backbone_1817
# prot_name:4FOB_backbone
# frame_name:_1817
# Final frame_name:1817
# full_name:4FOB_backbone_596
# prot_name:4FOB_backbone
# frame_name:_596
# Final frame_name:596
# full_name:4FOB_backbone_252
# prot_name:4FOB_backbone
# frame_name:_252
# Final frame_name:252
# full_name:4FOB_backbone_1475
# prot_name:4FOB_backbone
# frame_name:_1475
# Final frame_name:1475
# full_name:4FOB_backbone_1524
# prot_name:4FOB_backbone
# frame_name:_1524
# Final frame_name:1524
# full_name:4FOB_backbone_1095
# prot_name:4FOB_backbone
# frame_name:_1095
# Final frame_name:1095
# full_name:4FOB_backbone_1408
# prot_name:4FOB_backbone
# frame_name:_1408
# Final frame_name:1408
# full_name:4FOB_backbone_724
# prot_name:4FOB_backbone
# frame_name:_724
# Final frame_name:724
# full_name:4FOB_backbone_2734
# prot_name:4FOB_backbone
# frame_name:_2734
# Final frame_name:2734
# full_name:4FOB_backbone_2164
# prot_name:4FOB_backbone
# frame_name:_2164
# Final frame_name:2164
# full_name:4FOB_backbone_2297
# prot_name:4FOB_backbone
# frame_name:_2297
# Final frame_name:2297
# full_name:4FOB_backbone_2354
# prot_name:4FOB_backbone
# frame_name:_2354
# Final frame_name:2354
# full_name:4FOB_backbone_1086
# prot_name:4FOB_backbone
# frame_name:_1086
# Final frame_name:1086
# full_name:4FOB_backbone_641
# prot_name:4FOB_backbone
# frame_name:_641
# Final frame_name:641
# full_name:4FOB_backbone_2408
# prot_name:4FOB_backbone
# frame_name:_2408
# Final frame_name:2408
# full_name:4FOB_backbone_909
# prot_name:4FOB_backbone
# frame_name:_909
# Final frame_name:909
# full_name:4FOB_backbone_931
# prot_name:4FOB_backbone
# frame_name:_931
# Final frame_name:931
# full_name:4FOB_backbone_1923
# prot_name:4FOB_backbone
# frame_name:_1923
# Final frame_name:1923
# full_name:4FOB_backbone_169
# prot_name:4FOB_backbone
# frame_name:_169
# Final frame_name:169
# full_name:4FOB_backbone_24
# prot_name:4FOB_backbone
# frame_name:_24
# Final frame_name:24
# full_name:4FOB_backbone_572
# prot_name:4FOB_backbone
# frame_name:_572
# Final frame_name:572
# full_name:4FOB_backbone_557
# prot_name:4FOB_backbone
# frame_name:_557
# Final frame_name:557
# full_name:4FOB_backbone_340
# prot_name:4FOB_backbone
# frame_name:_340
# Final frame_name:340
# full_name:4FOB_backbone_65
# prot_name:4FOB_backbone
# frame_name:_65
# Final frame_name:65
# full_name:4FOB_backbone_1474
# prot_name:4FOB_backbone
# frame_name:_1474
# Final frame_name:1474
# full_name:4FOB_backbone_1734
# prot_name:4FOB_backbone
# frame_name:_1734
# Final frame_name:1734
# full_name:4FOB_backbone_1124
# prot_name:4FOB_backbone
# frame_name:_1124
# Final frame_name:1124
# full_name:4FOB_backbone_308
# prot_name:4FOB_backbone
# frame_name:_308
# Final frame_name:308
# full_name:4FOB_backbone_1226
# prot_name:4FOB_backbone
# frame_name:_1226
# Final frame_name:1226
# full_name:4FOB_backbone_652
# prot_name:4FOB_backbone
# frame_name:_652
# Final frame_name:652
# full_name:4FOB_backbone_1680
# prot_name:4FOB_backbone
# frame_name:_1680
# Final frame_name:1680
# full_name:4FOB_backbone_1805
# prot_name:4FOB_backbone
# frame_name:_1805
# Final frame_name:1805
# full_name:4FOB_backbone_1755
# prot_name:4FOB_backbone
# frame_name:_1755
# Final frame_name:1755
# full_name:4FOB_backbone_1453
# prot_name:4FOB_backbone
# frame_name:_1453
# Final frame_name:1453
# full_name:4FOB_backbone_1716
# prot_name:4FOB_backbone
# frame_name:_1716
# Final frame_name:1716
# full_name:4FOB_backbone_799
# prot_name:4FOB_backbone
# frame_name:_799
# Final frame_name:799
# full_name:4FOB_backbone_1074
# prot_name:4FOB_backbone
# frame_name:_1074
# Final frame_name:1074
# full_name:4FOB_backbone_335
# prot_name:4FOB_backbone
# frame_name:_335
# Final frame_name:335
# full_name:4FOB_backbone_1023
# prot_name:4FOB_backbone
# frame_name:_1023
# Final frame_name:1023
# full_name:4FOB_backbone_2523
# prot_name:4FOB_backbone
# frame_name:_2523
# Final frame_name:2523
# full_name:4FOB_backbone_1340
# prot_name:4FOB_backbone
# frame_name:_1340
# Final frame_name:1340
# full_name:4FOB_backbone_1030
# prot_name:4FOB_backbone
# frame_name:_1030
# Final frame_name:1030
# full_name:4FOB_backbone_1600
# prot_name:4FOB_backbone
# frame_name:_1600
# Final frame_name:1600
# full_name:4FOB_backbone_0
# prot_name:4FOB_backbone
# frame_name:_0
# Final frame_name:0
# full_name:4FOB_backbone_2294
# prot_name:4FOB_backbone
# frame_name:_2294
# Final frame_name:2294
# full_name:4FOB_backbone_1112
# prot_name:4FOB_backbone
# frame_name:_1112
# Final frame_name:1112
# full_name:4FOB_backbone_858
# prot_name:4FOB_backbone
# frame_name:_858
# Final frame_name:858
# full_name:4FOB_backbone_2010
# prot_name:4FOB_backbone
# frame_name:_2010
# Final frame_name:2010
# full_name:4FOB_backbone_420
# prot_name:4FOB_backbone
# frame_name:_420
# Final frame_name:420
# full_name:4FOB_backbone_1472
# prot_name:4FOB_backbone
# frame_name:_1472
# Final frame_name:1472
# full_name:4FOB_backbone_336
# prot_name:4FOB_backbone
# frame_name:_336
# Final frame_name:336
# full_name:4FOB_backbone_2727
# prot_name:4FOB_backbone
# frame_name:_2727
# Final frame_name:2727
# full_name:4FOB_backbone_1389
# prot_name:4FOB_backbone
# frame_name:_1389
# Final frame_name:1389
# full_name:4FOB_backbone_111
# prot_name:4FOB_backbone
# frame_name:_111
# Final frame_name:111
# full_name:4FOB_backbone_2250
# prot_name:4FOB_backbone
# frame_name:_2250
# Final frame_name:2250
# full_name:4FOB_backbone_757
# prot_name:4FOB_backbone
# frame_name:_757
# Final frame_name:757
# full_name:4FOB_backbone_1551
# prot_name:4FOB_backbone
# frame_name:_1551
# Final frame_name:1551
# full_name:4FOB_backbone_104
# prot_name:4FOB_backbone
# frame_name:_104
# Final frame_name:104
# full_name:4FOB_backbone_664
# prot_name:4FOB_backbone
# frame_name:_664
# Final frame_name:664
# full_name:4FOB_backbone_1814
# prot_name:4FOB_backbone
# frame_name:_1814
# Final frame_name:1814
# full_name:4FOB_backbone_2623
# prot_name:4FOB_backbone
# frame_name:_2623
# Final frame_name:2623
# full_name:4FOB_backbone_125
# prot_name:4FOB_backbone
# frame_name:_125
# Final frame_name:125
# full_name:4FOB_backbone_455
# prot_name:4FOB_backbone
# frame_name:_455
# Final frame_name:455
# full_name:4FOB_backbone_2562
# prot_name:4FOB_backbone
# frame_name:_2562
# Final frame_name:2562
# full_name:4FOB_backbone_219
# prot_name:4FOB_backbone
# frame_name:_219
# Final frame_name:219
# full_name:4FOB_backbone_1470
# prot_name:4FOB_backbone
# frame_name:_1470
# Final frame_name:1470
# full_name:4FOB_backbone_1320
# prot_name:4FOB_backbone
# frame_name:_1320
# Final frame_name:1320
# full_name:4FOB_backbone_491
# prot_name:4FOB_backbone
# frame_name:_491
# Final frame_name:491
# full_name:4FOB_backbone_2440
# prot_name:4FOB_backbone
# frame_name:_2440
# Final frame_name:2440
# full_name:4FOB_backbone_2652
# prot_name:4FOB_backbone
# frame_name:_2652
# Final frame_name:2652
# full_name:4FOB_backbone_1818
# prot_name:4FOB_backbone
# frame_name:_1818
# Final frame_name:1818
# full_name:4FOB_backbone_2111
# prot_name:4FOB_backbone
# frame_name:_2111
# Final frame_name:2111
# full_name:4FOB_backbone_1359
# prot_name:4FOB_backbone
# frame_name:_1359
# Final frame_name:1359
# full_name:4FOB_backbone_1388
# prot_name:4FOB_backbone
# frame_name:_1388
# Final frame_name:1388
# full_name:4FOB_backbone_1284
# prot_name:4FOB_backbone
# frame_name:_1284
# Final frame_name:1284
# full_name:4FOB_backbone_143
# prot_name:4FOB_backbone
# frame_name:_143
# Final frame_name:143
# full_name:4FOB_backbone_676
# prot_name:4FOB_backbone
# frame_name:_676
# Final frame_name:676
# full_name:4FOB_backbone_2403
# prot_name:4FOB_backbone
# frame_name:_2403
# Final frame_name:2403
# full_name:4FOB_backbone_2114
# prot_name:4FOB_backbone
# frame_name:_2114
# Final frame_name:2114
# full_name:4FOB_backbone_866
# prot_name:4FOB_backbone
# frame_name:_866
# Final frame_name:866
# full_name:4FOB_backbone_18
# prot_name:4FOB_backbone
# frame_name:_18
# Final frame_name:18
# full_name:4FOB_backbone_2602
# prot_name:4FOB_backbone
# frame_name:_2602
# Final frame_name:2602
# full_name:4FOB_backbone_2698
# prot_name:4FOB_backbone
# frame_name:_2698
# Final frame_name:2698
# full_name:4FOB_backbone_746
# prot_name:4FOB_backbone
# frame_name:_746
# Final frame_name:746
# full_name:4FOB_backbone_1675
# prot_name:4FOB_backbone
# frame_name:_1675
# Final frame_name:1675
# full_name:4FOB_backbone_1315
# prot_name:4FOB_backbone
# frame_name:_1315
# Final frame_name:1315
# full_name:4FOB_backbone_1506
# prot_name:4FOB_backbone
# frame_name:_1506
# Final frame_name:1506
# full_name:4FOB_backbone_826
# prot_name:4FOB_backbone
# frame_name:_826
# Final frame_name:826
# full_name:4FOB_backbone_409
# prot_name:4FOB_backbone
# frame_name:_409
# Final frame_name:409
# full_name:4FOB_backbone_2524
# prot_name:4FOB_backbone
# frame_name:_2524
# Final frame_name:2524
# full_name:4FOB_backbone_575
# prot_name:4FOB_backbone
# frame_name:_575
# Final frame_name:575
# full_name:4FOB_backbone_1767
# prot_name:4FOB_backbone
# frame_name:_1767
# Final frame_name:1767
# full_name:4FOB_backbone_1732
# prot_name:4FOB_backbone
# frame_name:_1732
# Final frame_name:1732
# full_name:4FOB_backbone_289
# prot_name:4FOB_backbone
# frame_name:_289
# Final frame_name:289
# full_name:4FOB_backbone_501
# prot_name:4FOB_backbone
# frame_name:_501
# Final frame_name:501
# full_name:4FOB_backbone_2246
# prot_name:4FOB_backbone
# frame_name:_2246
# Final frame_name:2246
# full_name:4FOB_backbone_1187
# prot_name:4FOB_backbone
# frame_name:_1187
# Final frame_name:1187
# full_name:4FOB_backbone_624
# prot_name:4FOB_backbone
# frame_name:_624
# Final frame_name:624
# full_name:4FOB_backbone_685
# prot_name:4FOB_backbone
# frame_name:_685
# Final frame_name:685
# full_name:4FOB_backbone_1119
# prot_name:4FOB_backbone
# frame_name:_1119
# Final frame_name:1119
# full_name:4FOB_backbone_362
# prot_name:4FOB_backbone
# frame_name:_362
# Final frame_name:362
# full_name:4FOB_backbone_974
# prot_name:4FOB_backbone
# frame_name:_974
# Final frame_name:974
# full_name:4FOB_backbone_2579
# prot_name:4FOB_backbone
# frame_name:_2579
# Final frame_name:2579
# full_name:4FOB_backbone_1126
# prot_name:4FOB_backbone
# frame_name:_1126
# Final frame_name:1126
# full_name:4FOB_backbone_2130
# prot_name:4FOB_backbone
# frame_name:_2130
# Final frame_name:2130
# full_name:4FOB_backbone_649
# prot_name:4FOB_backbone
# frame_name:_649
# Final frame_name:649
# full_name:4FOB_backbone_464
# prot_name:4FOB_backbone
# frame_name:_464
# Final frame_name:464
# full_name:4FOB_backbone_2482
# prot_name:4FOB_backbone
# frame_name:_2482
# Final frame_name:2482
# full_name:4FOB_backbone_1503
# prot_name:4FOB_backbone
# frame_name:_1503
# Final frame_name:1503
# full_name:4FOB_backbone_1219
# prot_name:4FOB_backbone
# frame_name:_1219
# Final frame_name:1219
# full_name:4FOB_backbone_393
# prot_name:4FOB_backbone
# frame_name:_393
# Final frame_name:393
# full_name:4FOB_backbone_1188
# prot_name:4FOB_backbone
# frame_name:_1188
# Final frame_name:1188
# full_name:4FOB_backbone_2016
# prot_name:4FOB_backbone
# frame_name:_2016
# Final frame_name:2016
# full_name:4FOB_backbone_916
# prot_name:4FOB_backbone
# frame_name:_916
# Final frame_name:916
# full_name:4FOB_backbone_2126
# prot_name:4FOB_backbone
# frame_name:_2126
# Final frame_name:2126
# full_name:4FOB_backbone_2179
# prot_name:4FOB_backbone
# frame_name:_2179
# Final frame_name:2179
# full_name:4FOB_backbone_523
# prot_name:4FOB_backbone
# frame_name:_523
# Final frame_name:523
# full_name:4FOB_backbone_1849
# prot_name:4FOB_backbone
# frame_name:_1849
# Final frame_name:1849
# full_name:4FOB_backbone_451
# prot_name:4FOB_backbone
# frame_name:_451
# Final frame_name:451
# full_name:4FOB_backbone_1901
# prot_name:4FOB_backbone
# frame_name:_1901
# Final frame_name:1901
# full_name:4FOB_backbone_2480
# prot_name:4FOB_backbone
# frame_name:_2480
# Final frame_name:2480
# full_name:4FOB_backbone_2303
# prot_name:4FOB_backbone
# frame_name:_2303
# Final frame_name:2303
# full_name:4FOB_backbone_509
# prot_name:4FOB_backbone
# frame_name:_509
# Final frame_name:509
# full_name:4FOB_backbone_2495
# prot_name:4FOB_backbone
# frame_name:_2495
# Final frame_name:2495
# full_name:4FOB_backbone_1243
# prot_name:4FOB_backbone
# frame_name:_1243
# Final frame_name:1243
# full_name:4FOB_backbone_2060
# prot_name:4FOB_backbone
# frame_name:_2060
# Final frame_name:2060
# full_name:4FOB_backbone_285
# prot_name:4FOB_backbone
# frame_name:_285
# Final frame_name:285
# full_name:4FOB_backbone_1669
# prot_name:4FOB_backbone
# frame_name:_1669
# Final frame_name:1669
# full_name:4FOB_backbone_761
# prot_name:4FOB_backbone
# frame_name:_761
# Final frame_name:761
# full_name:4FOB_backbone_1228
# prot_name:4FOB_backbone
# frame_name:_1228
# Final frame_name:1228
# full_name:4FOB_backbone_917
# prot_name:4FOB_backbone
# frame_name:_917
# Final frame_name:917
# full_name:4FOB_backbone_2011
# prot_name:4FOB_backbone
# frame_name:_2011
# Final frame_name:2011
# full_name:4FOB_backbone_2663
# prot_name:4FOB_backbone
# frame_name:_2663
# Final frame_name:2663
# full_name:4FOB_backbone_2594
# prot_name:4FOB_backbone
# frame_name:_2594
# Final frame_name:2594
# full_name:4FOB_backbone_152
# prot_name:4FOB_backbone
# frame_name:_152
# Final frame_name:152
# full_name:4FOB_backbone_2344
# prot_name:4FOB_backbone
# frame_name:_2344
# Final frame_name:2344
# full_name:4FOB_backbone_598
# prot_name:4FOB_backbone
# frame_name:_598
# Final frame_name:598
# full_name:4FOB_backbone_2406
# prot_name:4FOB_backbone
# frame_name:_2406
# Final frame_name:2406
# full_name:4FOB_backbone_66
# prot_name:4FOB_backbone
# frame_name:_66
# Final frame_name:66
# full_name:4FOB_backbone_452
# prot_name:4FOB_backbone
# frame_name:_452
# Final frame_name:452
# full_name:4FOB_backbone_1485
# prot_name:4FOB_backbone
# frame_name:_1485
# Final frame_name:1485
# full_name:4FOB_backbone_320
# prot_name:4FOB_backbone
# frame_name:_320
# Final frame_name:320
# full_name:4FOB_backbone_1426
# prot_name:4FOB_backbone
# frame_name:_1426
# Final frame_name:1426
# full_name:4FOB_backbone_620
# prot_name:4FOB_backbone
# frame_name:_620
# Final frame_name:620
# full_name:4FOB_backbone_1808
# prot_name:4FOB_backbone
# frame_name:_1808
# Final frame_name:1808
# full_name:4FOB_backbone_1972
# prot_name:4FOB_backbone
# frame_name:_1972
# Final frame_name:1972
# full_name:4FOB_backbone_1728
# prot_name:4FOB_backbone
# frame_name:_1728
# Final frame_name:1728
# full_name:4FOB_backbone_628
# prot_name:4FOB_backbone
# frame_name:_628
# Final frame_name:628
# full_name:4FOB_backbone_1195
# prot_name:4FOB_backbone
# frame_name:_1195
# Final frame_name:1195
# full_name:4FOB_backbone_2262
# prot_name:4FOB_backbone
# frame_name:_2262
# Final frame_name:2262
# full_name:4FOB_backbone_1844
# prot_name:4FOB_backbone
# frame_name:_1844
# Final frame_name:1844
# full_name:4FOB_backbone_427
# prot_name:4FOB_backbone
# frame_name:_427
# Final frame_name:427
# full_name:4FOB_backbone_222
# prot_name:4FOB_backbone
# frame_name:_222
# Final frame_name:222
# full_name:4FOB_backbone_1450
# prot_name:4FOB_backbone
# frame_name:_1450
# Final frame_name:1450
# full_name:4FOB_backbone_2095
# prot_name:4FOB_backbone
# frame_name:_2095
# Final frame_name:2095
# full_name:4FOB_backbone_1230
# prot_name:4FOB_backbone
# frame_name:_1230
# Final frame_name:1230
# full_name:4FOB_backbone_1911
# prot_name:4FOB_backbone
# frame_name:_1911
# Final frame_name:1911
# full_name:4FOB_backbone_1223
# prot_name:4FOB_backbone
# frame_name:_1223
# Final frame_name:1223
# full_name:4FOB_backbone_2687
# prot_name:4FOB_backbone
# frame_name:_2687
# Final frame_name:2687
# full_name:4FOB_backbone_2481
# prot_name:4FOB_backbone
# frame_name:_2481
# Final frame_name:2481
# full_name:4FOB_backbone_2337
# prot_name:4FOB_backbone
# frame_name:_2337
# Final frame_name:2337
# full_name:4FOB_backbone_1289
# prot_name:4FOB_backbone
# frame_name:_1289
# Final frame_name:1289
# full_name:4FOB_backbone_2184
# prot_name:4FOB_backbone
# frame_name:_2184
# Final frame_name:2184
# full_name:4FOB_backbone_108
# prot_name:4FOB_backbone
# frame_name:_108
# Final frame_name:108
# full_name:4FOB_backbone_1293
# prot_name:4FOB_backbone
# frame_name:_1293
# Final frame_name:1293
# full_name:4FOB_backbone_1029
# prot_name:4FOB_backbone
# frame_name:_1029
# Final frame_name:1029
# full_name:4FOB_backbone_1977
# prot_name:4FOB_backbone
# frame_name:_1977
# Final frame_name:1977
# full_name:4FOB_backbone_1355
# prot_name:4FOB_backbone
# frame_name:_1355
# Final frame_name:1355
# full_name:4FOB_backbone_2209
# prot_name:4FOB_backbone
# frame_name:_2209
# Final frame_name:2209
# full_name:4FOB_backbone_2053
# prot_name:4FOB_backbone
# frame_name:_2053
# Final frame_name:2053
# full_name:4FOB_backbone_992
# prot_name:4FOB_backbone
# frame_name:_992
# Final frame_name:992
# full_name:4FOB_backbone_2231
# prot_name:4FOB_backbone
# frame_name:_2231
# Final frame_name:2231
# full_name:4FOB_backbone_2591
# prot_name:4FOB_backbone
# frame_name:_2591
# Final frame_name:2591
# full_name:4FOB_backbone_2148
# prot_name:4FOB_backbone
# frame_name:_2148
# Final frame_name:2148
# full_name:4FOB_backbone_1050
# prot_name:4FOB_backbone
# frame_name:_1050
# Final frame_name:1050
# full_name:4FOB_backbone_306
# prot_name:4FOB_backbone
# frame_name:_306
# Final frame_name:306
# full_name:4FOB_backbone_1970
# prot_name:4FOB_backbone
# frame_name:_1970
# Final frame_name:1970
# full_name:4FOB_backbone_1978
# prot_name:4FOB_backbone
# frame_name:_1978
# Final frame_name:1978
# full_name:4FOB_backbone_1349
# prot_name:4FOB_backbone
# frame_name:_1349
# Final frame_name:1349
# full_name:4FOB_backbone_842
# prot_name:4FOB_backbone
# frame_name:_842
# Final frame_name:842
# full_name:4FOB_backbone_1420
# prot_name:4FOB_backbone
# frame_name:_1420
# Final frame_name:1420
# full_name:4FOB_backbone_1177
# prot_name:4FOB_backbone
# frame_name:_1177
# Final frame_name:1177
# full_name:4FOB_backbone_1525
# prot_name:4FOB_backbone
# frame_name:_1525
# Final frame_name:1525
# full_name:4FOB_backbone_211
# prot_name:4FOB_backbone
# frame_name:_211
# Final frame_name:211
# full_name:4FOB_backbone_2342
# prot_name:4FOB_backbone
# frame_name:_2342
# Final frame_name:2342
# full_name:4FOB_backbone_1548
# prot_name:4FOB_backbone
# frame_name:_1548
# Final frame_name:1548
# full_name:4FOB_backbone_806
# prot_name:4FOB_backbone
# frame_name:_806
# Final frame_name:806
# full_name:4FOB_backbone_1833
# prot_name:4FOB_backbone
# frame_name:_1833
# Final frame_name:1833
# full_name:4FOB_backbone_2119
# prot_name:4FOB_backbone
# frame_name:_2119
# Final frame_name:2119
# full_name:4FOB_backbone_2570
# prot_name:4FOB_backbone
# frame_name:_2570
# Final frame_name:2570
# full_name:4FOB_backbone_1971
# prot_name:4FOB_backbone
# frame_name:_1971
# Final frame_name:1971
# full_name:4FOB_backbone_1092
# prot_name:4FOB_backbone
# frame_name:_1092
# Final frame_name:1092
# full_name:4FOB_backbone_1726
# prot_name:4FOB_backbone
# frame_name:_1726
# Final frame_name:1726
# full_name:4FOB_backbone_416
# prot_name:4FOB_backbone
# frame_name:_416
# Final frame_name:416
# full_name:4FOB_backbone_235
# prot_name:4FOB_backbone
# frame_name:_235
# Final frame_name:235
# full_name:4FOB_backbone_2026
# prot_name:4FOB_backbone
# frame_name:_2026
# Final frame_name:2026
# full_name:4FOB_backbone_488
# prot_name:4FOB_backbone
# frame_name:_488
# Final frame_name:488
# full_name:4FOB_backbone_136
# prot_name:4FOB_backbone
# frame_name:_136
# Final frame_name:136
# full_name:4FOB_backbone_421
# prot_name:4FOB_backbone
# frame_name:_421
# Final frame_name:421
# full_name:4FOB_backbone_1432
# prot_name:4FOB_backbone
# frame_name:_1432
# Final frame_name:1432
# full_name:4FOB_backbone_1936
# prot_name:4FOB_backbone
# frame_name:_1936
# Final frame_name:1936
# full_name:4FOB_backbone_151
# prot_name:4FOB_backbone
# frame_name:_151
# Final frame_name:151
# full_name:4FOB_backbone_958
# prot_name:4FOB_backbone
# frame_name:_958
# Final frame_name:958
# full_name:4FOB_backbone_465
# prot_name:4FOB_backbone
# frame_name:_465
# Final frame_name:465
# full_name:4FOB_backbone_1505
# prot_name:4FOB_backbone
# frame_name:_1505
# Final frame_name:1505
# full_name:4FOB_backbone_2049
# prot_name:4FOB_backbone
# frame_name:_2049
# Final frame_name:2049
# full_name:4FOB_backbone_2195
# prot_name:4FOB_backbone
# frame_name:_2195
# Final frame_name:2195
# full_name:4FOB_backbone_1985
# prot_name:4FOB_backbone
# frame_name:_1985
# Final frame_name:1985
# full_name:4FOB_backbone_1512
# prot_name:4FOB_backbone
# frame_name:_1512
# Final frame_name:1512
# full_name:4FOB_backbone_2662
# prot_name:4FOB_backbone
# frame_name:_2662
# Final frame_name:2662
# full_name:4FOB_backbone_742
# prot_name:4FOB_backbone
# frame_name:_742
# Final frame_name:742
# full_name:4FOB_backbone_2410
# prot_name:4FOB_backbone
# frame_name:_2410
# Final frame_name:2410
# full_name:4FOB_backbone_732
# prot_name:4FOB_backbone
# frame_name:_732
# Final frame_name:732
# full_name:4FOB_backbone_205
# prot_name:4FOB_backbone
# frame_name:_205
# Final frame_name:205
# full_name:4FOB_backbone_215
# prot_name:4FOB_backbone
# frame_name:_215
# Final frame_name:215
# full_name:4FOB_backbone_259
# prot_name:4FOB_backbone
# frame_name:_259
# Final frame_name:259
# full_name:4FOB_backbone_1753
# prot_name:4FOB_backbone
# frame_name:_1753
# Final frame_name:1753
# full_name:4FOB_backbone_1773
# prot_name:4FOB_backbone
# frame_name:_1773
# Final frame_name:1773
# full_name:4FOB_backbone_2259
# prot_name:4FOB_backbone
# frame_name:_2259
# Final frame_name:2259
# full_name:4FOB_backbone_1660
# prot_name:4FOB_backbone
# frame_name:_1660
# Final frame_name:1660
# full_name:4FOB_backbone_1424
# prot_name:4FOB_backbone
# frame_name:_1424
# Final frame_name:1424
# full_name:4FOB_backbone_2638
# prot_name:4FOB_backbone
# frame_name:_2638
# Final frame_name:2638
# full_name:4FOB_backbone_2696
# prot_name:4FOB_backbone
# frame_name:_2696
# Final frame_name:2696
# full_name:4FOB_backbone_745
# prot_name:4FOB_backbone
# frame_name:_745
# Final frame_name:745
# full_name:4FOB_backbone_913
# prot_name:4FOB_backbone
# frame_name:_913
# Final frame_name:913
# full_name:4FOB_backbone_1000
# prot_name:4FOB_backbone
# frame_name:_1000
# Final frame_name:1000
# full_name:4FOB_backbone_1998
# prot_name:4FOB_backbone
# frame_name:_1998
# Final frame_name:1998
# full_name:4FOB_backbone_489
# prot_name:4FOB_backbone
# frame_name:_489
# Final frame_name:489
# full_name:4FOB_backbone_2272
# prot_name:4FOB_backbone
# frame_name:_2272
# Final frame_name:2272
# full_name:4FOB_backbone_312
# prot_name:4FOB_backbone
# frame_name:_312
# Final frame_name:312
# full_name:4FOB_backbone_2721
# prot_name:4FOB_backbone
# frame_name:_2721
# Final frame_name:2721
# full_name:4FOB_backbone_1436
# prot_name:4FOB_backbone
# frame_name:_1436
# Final frame_name:1436
# full_name:4FOB_backbone_1628
# prot_name:4FOB_backbone
# frame_name:_1628
# Final frame_name:1628
# full_name:4FOB_backbone_87
# prot_name:4FOB_backbone
# frame_name:_87
# Final frame_name:87
# full_name:4FOB_backbone_2360
# prot_name:4FOB_backbone
# frame_name:_2360
# Final frame_name:2360
# full_name:4FOB_backbone_1696
# prot_name:4FOB_backbone
# frame_name:_1696
# Final frame_name:1696
# full_name:4FOB_backbone_1790
# prot_name:4FOB_backbone
# frame_name:_1790
# Final frame_name:1790
# full_name:4FOB_backbone_2426
# prot_name:4FOB_backbone
# frame_name:_2426
# Final frame_name:2426
# full_name:4FOB_backbone_2330
# prot_name:4FOB_backbone
# frame_name:_2330
# Final frame_name:2330
# full_name:4FOB_backbone_2159
# prot_name:4FOB_backbone
# frame_name:_2159
# Final frame_name:2159
# full_name:4FOB_backbone_245
# prot_name:4FOB_backbone
# frame_name:_245
# Final frame_name:245
# full_name:4FOB_backbone_1093
# prot_name:4FOB_backbone
# frame_name:_1093
# Final frame_name:1093
# full_name:4FOB_backbone_172
# prot_name:4FOB_backbone
# frame_name:_172
# Final frame_name:172
# full_name:4FOB_backbone_383
# prot_name:4FOB_backbone
# frame_name:_383
# Final frame_name:383
# full_name:4FOB_backbone_2135
# prot_name:4FOB_backbone
# frame_name:_2135
# Final frame_name:2135
# full_name:4FOB_backbone_10
# prot_name:4FOB_backbone
# frame_name:_10
# Final frame_name:10
# full_name:4FOB_backbone_2583
# prot_name:4FOB_backbone
# frame_name:_2583
# Final frame_name:2583
# full_name:4FOB_backbone_687
# prot_name:4FOB_backbone
# frame_name:_687
# Final frame_name:687
# full_name:4FOB_backbone_2650
# prot_name:4FOB_backbone
# frame_name:_2650
# Final frame_name:2650
# full_name:4FOB_backbone_1385
# prot_name:4FOB_backbone
# frame_name:_1385
# Final frame_name:1385
# full_name:4FOB_backbone_1942
# prot_name:4FOB_backbone
# frame_name:_1942
# Final frame_name:1942
# full_name:4FOB_backbone_2198
# prot_name:4FOB_backbone
# frame_name:_2198
# Final frame_name:2198
# full_name:4FOB_backbone_1311
# prot_name:4FOB_backbone
# frame_name:_1311
# Final frame_name:1311
# full_name:4FOB_backbone_811
# prot_name:4FOB_backbone
# frame_name:_811
# Final frame_name:811
# full_name:4FOB_backbone_983
# prot_name:4FOB_backbone
# frame_name:_983
# Final frame_name:983
# full_name:4FOB_backbone_856
# prot_name:4FOB_backbone
# frame_name:_856
# Final frame_name:856
# full_name:4FOB_backbone_1983
# prot_name:4FOB_backbone
# frame_name:_1983
# Final frame_name:1983
# full_name:4FOB_backbone_2685
# prot_name:4FOB_backbone
# frame_name:_2685
# Final frame_name:2685
# full_name:4FOB_backbone_2321
# prot_name:4FOB_backbone
# frame_name:_2321
# Final frame_name:2321
# full_name:4FOB_backbone_785
# prot_name:4FOB_backbone
# frame_name:_785
# Final frame_name:785
# full_name:4FOB_backbone_1440
# prot_name:4FOB_backbone
# frame_name:_1440
# Final frame_name:1440
# full_name:4FOB_backbone_2462
# prot_name:4FOB_backbone
# frame_name:_2462
# Final frame_name:2462
# full_name:4FOB_backbone_1988
# prot_name:4FOB_backbone
# frame_name:_1988
# Final frame_name:1988
# full_name:4FOB_backbone_1130
# prot_name:4FOB_backbone
# frame_name:_1130
# Final frame_name:1130
# full_name:4FOB_backbone_2441
# prot_name:4FOB_backbone
# frame_name:_2441
# Final frame_name:2441
# full_name:4FOB_backbone_1623
# prot_name:4FOB_backbone
# frame_name:_1623
# Final frame_name:1623
# full_name:4FOB_backbone_2574
# prot_name:4FOB_backbone
# frame_name:_2574
# Final frame_name:2574
# full_name:4FOB_backbone_1271
# prot_name:4FOB_backbone
# frame_name:_1271
# Final frame_name:1271
# full_name:4FOB_backbone_723
# prot_name:4FOB_backbone
# frame_name:_723
# Final frame_name:723
# full_name:4FOB_backbone_2573
# prot_name:4FOB_backbone
# frame_name:_2573
# Final frame_name:2573
# full_name:4FOB_backbone_2556
# prot_name:4FOB_backbone
# frame_name:_2556
# Final frame_name:2556
# full_name:4FOB_backbone_2166
# prot_name:4FOB_backbone
# frame_name:_2166
# Final frame_name:2166
# full_name:4FOB_backbone_1241
# prot_name:4FOB_backbone
# frame_name:_1241
# Final frame_name:1241
# full_name:4FOB_backbone_2603
# prot_name:4FOB_backbone
# frame_name:_2603
# Final frame_name:2603
# full_name:4FOB_backbone_1530
# prot_name:4FOB_backbone
# frame_name:_1530
# Final frame_name:1530
# full_name:4FOB_backbone_1229
# prot_name:4FOB_backbone
# frame_name:_1229
# Final frame_name:1229
# full_name:4FOB_backbone_2454
# prot_name:4FOB_backbone
# frame_name:_2454
# Final frame_name:2454
# full_name:4FOB_backbone_1483
# prot_name:4FOB_backbone
# frame_name:_1483
# Final frame_name:1483
# full_name:4FOB_backbone_2704
# prot_name:4FOB_backbone
# frame_name:_2704
# Final frame_name:2704
# full_name:4FOB_backbone_1429
# prot_name:4FOB_backbone
# frame_name:_1429
# Final frame_name:1429
# full_name:4FOB_backbone_1922
# prot_name:4FOB_backbone
# frame_name:_1922
# Final frame_name:1922
# full_name:4FOB_backbone_73
# prot_name:4FOB_backbone
# frame_name:_73
# Final frame_name:73
# full_name:4FOB_backbone_550
# prot_name:4FOB_backbone
# frame_name:_550
# Final frame_name:550
# full_name:4FOB_backbone_857
# prot_name:4FOB_backbone
# frame_name:_857
# Final frame_name:857
# full_name:4FOB_backbone_2398
# prot_name:4FOB_backbone
# frame_name:_2398
# Final frame_name:2398
# full_name:4FOB_backbone_2205
# prot_name:4FOB_backbone
# frame_name:_2205
# Final frame_name:2205
# full_name:4FOB_backbone_2655
# prot_name:4FOB_backbone
# frame_name:_2655
# Final frame_name:2655
# full_name:4FOB_backbone_2043
# prot_name:4FOB_backbone
# frame_name:_2043
# Final frame_name:2043
# full_name:4FOB_backbone_1927
# prot_name:4FOB_backbone
# frame_name:_1927
# Final frame_name:1927
# full_name:4FOB_backbone_752
# prot_name:4FOB_backbone
# frame_name:_752
# Final frame_name:752
# full_name:4FOB_backbone_34
# prot_name:4FOB_backbone
# frame_name:_34
# Final frame_name:34
# full_name:4FOB_backbone_1258
# prot_name:4FOB_backbone
# frame_name:_1258
# Final frame_name:1258
# full_name:4FOB_backbone_1810
# prot_name:4FOB_backbone
# frame_name:_1810
# Final frame_name:1810
# full_name:4FOB_backbone_2079
# prot_name:4FOB_backbone
# frame_name:_2079
# Final frame_name:2079
# full_name:4FOB_backbone_1766
# prot_name:4FOB_backbone
# frame_name:_1766
# Final frame_name:1766
# full_name:4FOB_backbone_1294
# prot_name:4FOB_backbone
# frame_name:_1294
# Final frame_name:1294
# full_name:4FOB_backbone_1416
# prot_name:4FOB_backbone
# frame_name:_1416
# Final frame_name:1416
# full_name:4FOB_backbone_2085
# prot_name:4FOB_backbone
# frame_name:_2085
# Final frame_name:2085
# full_name:4FOB_backbone_1913
# prot_name:4FOB_backbone
# frame_name:_1913
# Final frame_name:1913
# full_name:4FOB_backbone_480
# prot_name:4FOB_backbone
# frame_name:_480
# Final frame_name:480
# full_name:4FOB_backbone_1446
# prot_name:4FOB_backbone
# frame_name:_1446
# Final frame_name:1446
# full_name:4FOB_backbone_2706
# prot_name:4FOB_backbone
# frame_name:_2706
# Final frame_name:2706
# full_name:4FOB_backbone_159
# prot_name:4FOB_backbone
# frame_name:_159
# Final frame_name:159
# full_name:4FOB_backbone_1895
# prot_name:4FOB_backbone
# frame_name:_1895
# Final frame_name:1895
# full_name:4FOB_backbone_2362
# prot_name:4FOB_backbone
# frame_name:_2362
# Final frame_name:2362
# full_name:4FOB_backbone_1685
# prot_name:4FOB_backbone
# frame_name:_1685
# Final frame_name:1685
# full_name:4FOB_backbone_906
# prot_name:4FOB_backbone
# frame_name:_906
# Final frame_name:906
# full_name:4FOB_backbone_1677
# prot_name:4FOB_backbone
# frame_name:_1677
# Final frame_name:1677
# full_name:4FOB_backbone_107
# prot_name:4FOB_backbone
# frame_name:_107
# Final frame_name:107
# full_name:4FOB_backbone_2429
# prot_name:4FOB_backbone
# frame_name:_2429
# Final frame_name:2429
# full_name:4FOB_backbone_227
# prot_name:4FOB_backbone
# frame_name:_227
# Final frame_name:227
# full_name:4FOB_backbone_2329
# prot_name:4FOB_backbone
# frame_name:_2329
# Final frame_name:2329
# full_name:4FOB_backbone_1233
# prot_name:4FOB_backbone
# frame_name:_1233
# Final frame_name:1233
# full_name:4FOB_backbone_1991
# prot_name:4FOB_backbone
# frame_name:_1991
# Final frame_name:1991
# full_name:4FOB_backbone_1264
# prot_name:4FOB_backbone
# frame_name:_1264
# Final frame_name:1264
# full_name:4FOB_backbone_1528
# prot_name:4FOB_backbone
# frame_name:_1528
# Final frame_name:1528
# full_name:4FOB_backbone_2661
# prot_name:4FOB_backbone
# frame_name:_2661
# Final frame_name:2661
# full_name:4FOB_backbone_1006
# prot_name:4FOB_backbone
# frame_name:_1006
# Final frame_name:1006
# full_name:4FOB_backbone_633
# prot_name:4FOB_backbone
# frame_name:_633
# Final frame_name:633
# full_name:4FOB_backbone_1587
# prot_name:4FOB_backbone
# frame_name:_1587
# Final frame_name:1587
# full_name:4FOB_backbone_1499
# prot_name:4FOB_backbone
# frame_name:_1499
# Final frame_name:1499
# full_name:4FOB_backbone_2512
# prot_name:4FOB_backbone
# frame_name:_2512
# Final frame_name:2512
# full_name:4FOB_backbone_1707
# prot_name:4FOB_backbone
# frame_name:_1707
# Final frame_name:1707
# full_name:4FOB_backbone_1221
# prot_name:4FOB_backbone
# frame_name:_1221
# Final frame_name:1221
# full_name:4FOB_backbone_770
# prot_name:4FOB_backbone
# frame_name:_770
# Final frame_name:770
# full_name:4FOB_backbone_1857
# prot_name:4FOB_backbone
# frame_name:_1857
# Final frame_name:1857
# full_name:4FOB_backbone_424
# prot_name:4FOB_backbone
# frame_name:_424
# Final frame_name:424
# full_name:4FOB_backbone_1392
# prot_name:4FOB_backbone
# frame_name:_1392
# Final frame_name:1392
# full_name:4FOB_backbone_2688
# prot_name:4FOB_backbone
# frame_name:_2688
# Final frame_name:2688
# full_name:4FOB_backbone_2601
# prot_name:4FOB_backbone
# frame_name:_2601
# Final frame_name:2601
# full_name:4FOB_backbone_1899
# prot_name:4FOB_backbone
# frame_name:_1899
# Final frame_name:1899
# full_name:4FOB_backbone_467
# prot_name:4FOB_backbone
# frame_name:_467
# Final frame_name:467
# full_name:4FOB_backbone_2008
# prot_name:4FOB_backbone
# frame_name:_2008
# Final frame_name:2008
# full_name:4FOB_backbone_202
# prot_name:4FOB_backbone
# frame_name:_202
# Final frame_name:202
# full_name:4FOB_backbone_2138
# prot_name:4FOB_backbone
# frame_name:_2138
# Final frame_name:2138
# full_name:4FOB_backbone_1370
# prot_name:4FOB_backbone
# frame_name:_1370
# Final frame_name:1370
# full_name:4FOB_backbone_37
# prot_name:4FOB_backbone
# frame_name:_37
# Final frame_name:37
# full_name:4FOB_backbone_1717
# prot_name:4FOB_backbone
# frame_name:_1717
# Final frame_name:1717
# full_name:4FOB_backbone_646
# prot_name:4FOB_backbone
# frame_name:_646
# Final frame_name:646
# full_name:4FOB_backbone_1037
# prot_name:4FOB_backbone
# frame_name:_1037
# Final frame_name:1037
# full_name:4FOB_backbone_1517
# prot_name:4FOB_backbone
# frame_name:_1517
# Final frame_name:1517
# full_name:4FOB_backbone_1795
# prot_name:4FOB_backbone
# frame_name:_1795
# Final frame_name:1795
# full_name:4FOB_backbone_899
# prot_name:4FOB_backbone
# frame_name:_899
# Final frame_name:899
# full_name:4FOB_backbone_2670
# prot_name:4FOB_backbone
# frame_name:_2670
# Final frame_name:2670
# full_name:4FOB_backbone_272
# prot_name:4FOB_backbone
# frame_name:_272
# Final frame_name:272
# full_name:4FOB_backbone_1367
# prot_name:4FOB_backbone
# frame_name:_1367
# Final frame_name:1367
# full_name:4FOB_backbone_53
# prot_name:4FOB_backbone
# frame_name:_53
# Final frame_name:53
# full_name:4FOB_backbone_2654
# prot_name:4FOB_backbone
# frame_name:_2654
# Final frame_name:2654
# full_name:4FOB_backbone_262
# prot_name:4FOB_backbone
# frame_name:_262
# Final frame_name:262
# full_name:4FOB_backbone_1437
# prot_name:4FOB_backbone
# frame_name:_1437
# Final frame_name:1437
# full_name:4FOB_backbone_781
# prot_name:4FOB_backbone
# frame_name:_781
# Final frame_name:781
# full_name:4FOB_backbone_910
# prot_name:4FOB_backbone
# frame_name:_910
# Final frame_name:910
# full_name:4FOB_backbone_2680
# prot_name:4FOB_backbone
# frame_name:_2680
# Final frame_name:2680
# full_name:4FOB_backbone_1277
# prot_name:4FOB_backbone
# frame_name:_1277
# Final frame_name:1277
# full_name:4FOB_backbone_717
# prot_name:4FOB_backbone
# frame_name:_717
# Final frame_name:717
# full_name:4FOB_backbone_62
# prot_name:4FOB_backbone
# frame_name:_62
# Final frame_name:62
# full_name:4FOB_backbone_398
# prot_name:4FOB_backbone
# frame_name:_398
# Final frame_name:398
# full_name:4FOB_backbone_937
# prot_name:4FOB_backbone
# frame_name:_937
# Final frame_name:937
# full_name:4FOB_backbone_934
# prot_name:4FOB_backbone
# frame_name:_934
# Final frame_name:934
# full_name:4FOB_backbone_748
# prot_name:4FOB_backbone
# frame_name:_748
# Final frame_name:748
# full_name:4FOB_backbone_1969
# prot_name:4FOB_backbone
# frame_name:_1969
# Final frame_name:1969
# full_name:4FOB_backbone_119
# prot_name:4FOB_backbone
# frame_name:_119
# Final frame_name:119
# full_name:4FOB_backbone_2693
# prot_name:4FOB_backbone
# frame_name:_2693
# Final frame_name:2693
# full_name:4FOB_backbone_1631
# prot_name:4FOB_backbone
# frame_name:_1631
# Final frame_name:1631
# full_name:4FOB_backbone_2422
# prot_name:4FOB_backbone
# frame_name:_2422
# Final frame_name:2422
# full_name:4FOB_backbone_898
# prot_name:4FOB_backbone
# frame_name:_898
# Final frame_name:898
# full_name:4FOB_backbone_1032
# prot_name:4FOB_backbone
# frame_name:_1032
# Final frame_name:1032
# full_name:4FOB_backbone_2021
# prot_name:4FOB_backbone
# frame_name:_2021
# Final frame_name:2021
# full_name:4FOB_backbone_1868
# prot_name:4FOB_backbone
# frame_name:_1868
# Final frame_name:1868
# full_name:4FOB_backbone_2719
# prot_name:4FOB_backbone
# frame_name:_2719
# Final frame_name:2719
# full_name:4FOB_backbone_1931
# prot_name:4FOB_backbone
# frame_name:_1931
# Final frame_name:1931
# full_name:4FOB_backbone_77
# prot_name:4FOB_backbone
# frame_name:_77
# Final frame_name:77
# full_name:4FOB_backbone_1629
# prot_name:4FOB_backbone
# frame_name:_1629
# Final frame_name:1629
# full_name:4FOB_backbone_1364
# prot_name:4FOB_backbone
# frame_name:_1364
# Final frame_name:1364
# full_name:4FOB_backbone_1605
# prot_name:4FOB_backbone
# frame_name:_1605
# Final frame_name:1605
# full_name:4FOB_backbone_201
# prot_name:4FOB_backbone
# frame_name:_201
# Final frame_name:201
# full_name:4FOB_backbone_1209
# prot_name:4FOB_backbone
# frame_name:_1209
# Final frame_name:1209
# full_name:4FOB_backbone_1190
# prot_name:4FOB_backbone
# frame_name:_1190
# Final frame_name:1190
# full_name:4FOB_backbone_2553
# prot_name:4FOB_backbone
# frame_name:_2553
# Final frame_name:2553
# full_name:4FOB_backbone_2134
# prot_name:4FOB_backbone
# frame_name:_2134
# Final frame_name:2134
# full_name:4FOB_backbone_2093
# prot_name:4FOB_backbone
# frame_name:_2093
# Final frame_name:2093
# full_name:4FOB_backbone_1915
# prot_name:4FOB_backbone
# frame_name:_1915
# Final frame_name:1915
# full_name:4FOB_backbone_953
# prot_name:4FOB_backbone
# frame_name:_953
# Final frame_name:953
# full_name:4FOB_backbone_243
# prot_name:4FOB_backbone
# frame_name:_243
# Final frame_name:243
# full_name:4FOB_backbone_1397
# prot_name:4FOB_backbone
# frame_name:_1397
# Final frame_name:1397
# full_name:4FOB_backbone_139
# prot_name:4FOB_backbone
# frame_name:_139
# Final frame_name:139
# full_name:4FOB_backbone_2733
# prot_name:4FOB_backbone
# frame_name:_2733
# Final frame_name:2733
# full_name:4FOB_backbone_2229
# prot_name:4FOB_backbone
# frame_name:_2229
# Final frame_name:2229
# full_name:4FOB_backbone_1405
# prot_name:4FOB_backbone
# frame_name:_1405
# Final frame_name:1405
# full_name:4FOB_backbone_1644
# prot_name:4FOB_backbone
# frame_name:_1644
# Final frame_name:1644
# full_name:4FOB_backbone_1748
# prot_name:4FOB_backbone
# frame_name:_1748
# Final frame_name:1748
# full_name:4FOB_backbone_247
# prot_name:4FOB_backbone
# frame_name:_247
# Final frame_name:247
# full_name:4FOB_backbone_237
# prot_name:4FOB_backbone
# frame_name:_237
# Final frame_name:237
# full_name:4FOB_backbone_2024
# prot_name:4FOB_backbone
# frame_name:_2024
# Final frame_name:2024
# full_name:4FOB_backbone_1825
# prot_name:4FOB_backbone
# frame_name:_1825
# Final frame_name:1825
# full_name:4FOB_backbone_1616
# prot_name:4FOB_backbone
# frame_name:_1616
# Final frame_name:1616
# full_name:4FOB_backbone_965
# prot_name:4FOB_backbone
# frame_name:_965
# Final frame_name:965
# full_name:4FOB_backbone_1819
# prot_name:4FOB_backbone
# frame_name:_1819
# Final frame_name:1819
# full_name:4FOB_backbone_1511
# prot_name:4FOB_backbone
# frame_name:_1511
# Final frame_name:1511
# full_name:4FOB_backbone_1321
# prot_name:4FOB_backbone
# frame_name:_1321
# Final frame_name:1321
# full_name:4FOB_backbone_1106
# prot_name:4FOB_backbone
# frame_name:_1106
# Final frame_name:1106
# full_name:4FOB_backbone_2471
# prot_name:4FOB_backbone
# frame_name:_2471
# Final frame_name:2471
# full_name:4FOB_backbone_1076
# prot_name:4FOB_backbone
# frame_name:_1076
# Final frame_name:1076
# full_name:4FOB_backbone_1279
# prot_name:4FOB_backbone
# frame_name:_1279
# Final frame_name:1279
# full_name:4FOB_backbone_2712
# prot_name:4FOB_backbone
# frame_name:_2712
# Final frame_name:2712
# full_name:4FOB_backbone_1659
# prot_name:4FOB_backbone
# frame_name:_1659
# Final frame_name:1659
# full_name:4FOB_backbone_2300
# prot_name:4FOB_backbone
# frame_name:_2300
# Final frame_name:2300
# full_name:4FOB_backbone_193
# prot_name:4FOB_backbone
# frame_name:_193
# Final frame_name:193
# full_name:4FOB_backbone_1747
# prot_name:4FOB_backbone
# frame_name:_1747
# Final frame_name:1747
# full_name:4FOB_backbone_524
# prot_name:4FOB_backbone
# frame_name:_524
# Final frame_name:524
# full_name:4FOB_backbone_1145
# prot_name:4FOB_backbone
# frame_name:_1145
# ...
# prot_name:4FOB_backbone
# frame_name:_1034
# Final frame_name:1034
# full_name:4FOB_backbone_406
# prot_name:4FOB_backbone
# frame_name:_406
# Final frame_name:406
# full_name:4FOB_backbone_2044
# prot_name:4FOB_backbone
# frame_name:_2044
# Final frame_name:2044
# full_name:4FOB_backbone_1850
# prot_name:4FOB_backbone
# frame_name:_1850
# Final frame_name:1850
# full_name:4FOB_backbone_1117
# prot_name:4FOB_backbone
# frame_name:_1117
# Final frame_name:1117
# full_name:4FOB_backbone_1682
# prot_name:4FOB_backbone
# frame_name:_1682
# Final frame_name:1682
# full_name:4FOB_backbone_1579
# prot_name:4FOB_backbone
# frame_name:_1579
# Final frame_name:1579
# full_name:4FOB_backbone_492
# prot_name:4FOB_backbone
# frame_name:_492
# Final frame_name:492
# full_name:4FOB_backbone_932
# prot_name:4FOB_backbone
# frame_name:_932
# Final frame_name:932
# full_name:4FOB_backbone_610
# prot_name:4FOB_backbone
# frame_name:_610
# Final frame_name:610
# full_name:4FOB_backbone_110
# prot_name:4FOB_backbone
# frame_name:_110
# Final frame_name:110
# full_name:4FOB_backbone_2000
# prot_name:4FOB_backbone
# frame_name:_2000
# Final frame_name:2000
# full_name:4FOB_backbone_2110
# prot_name:4FOB_backbone
# frame_name:_2110
# Final frame_name:2110
# full_name:4FOB_backbone_2483
# prot_name:4FOB_backbone
# frame_name:_2483
# Final frame_name:2483
# full_name:4FOB_backbone_1138
# prot_name:4FOB_backbone
# frame_name:_1138
# Final frame_name:1138
# full_name:4FOB_backbone_2146
# prot_name:4FOB_backbone
# frame_name:_2146
# Final frame_name:2146
# full_name:4FOB_backbone_1150
# prot_name:4FOB_backbone
# frame_name:_1150
# Final frame_name:1150
# full_name:4FOB_backbone_753
# prot_name:4FOB_backbone
# frame_name:_753
# Final frame_name:753
# full_name:4FOB_backbone_1318
# prot_name:4FOB_backbone
# frame_name:_1318
# Final frame_name:1318
# full_name:4FOB_backbone_2447
# prot_name:4FOB_backbone
# frame_name:_2447
# Final frame_name:2447
# full_name:4FOB_backbone_385
# prot_name:4FOB_backbone
# frame_name:_385
# Final frame_name:385
# full_name:4FOB_backbone_1847
# prot_name:4FOB_backbone
# frame_name:_1847
# Final frame_name:1847
# full_name:4FOB_backbone_2313
# prot_name:4FOB_backbone
# frame_name:_2313
# Final frame_name:2313
# full_name:4FOB_backbone_828
# prot_name:4FOB_backbone
# frame_name:_828
# Final frame_name:828
# full_name:4FOB_backbone_1526
# prot_name:4FOB_backbone
# frame_name:_1526
# Final frame_name:1526
# full_name:4FOB_backbone_2207
# prot_name:4FOB_backbone
# frame_name:_2207
# Final frame_name:2207
# full_name:4FOB_backbone_2657
# prot_name:4FOB_backbone
# frame_name:_2657
# Final frame_name:2657
# full_name:4FOB_backbone_1033
# prot_name:4FOB_backbone
# frame_name:_1033
# Final frame_name:1033
# full_name:4FOB_backbone_2608
# prot_name:4FOB_backbone
# frame_name:_2608
# Final frame_name:2608
# full_name:4FOB_backbone_2222
# prot_name:4FOB_backbone
# frame_name:_2222
# Final frame_name:2222
# full_name:4FOB_backbone_1619
# prot_name:4FOB_backbone
# frame_name:_1619
# Final frame_name:1619
# full_name:4FOB_backbone_323
# prot_name:4FOB_backbone
# frame_name:_323
# Final frame_name:323
# full_name:4FOB_backbone_39
# prot_name:4FOB_backbone
# frame_name:_39
# Final frame_name:39
# full_name:4FOB_backbone_1390
# prot_name:4FOB_backbone
# frame_name:_1390
# Final frame_name:1390
# full_name:4FOB_backbone_1920
# prot_name:4FOB_backbone
# frame_name:_1920
# Final frame_name:1920
# full_name:4FOB_backbone_2634
# prot_name:4FOB_backbone
# frame_name:_2634
# Final frame_name:2634
# full_name:4FOB_backbone_2545
# prot_name:4FOB_backbone
# frame_name:_2545
# Final frame_name:2545
# full_name:4FOB_backbone_2293
# prot_name:4FOB_backbone
# frame_name:_2293
# Final frame_name:2293
# full_name:4FOB_backbone_1350
# prot_name:4FOB_backbone
# frame_name:_1350
# Final frame_name:1350
# full_name:4FOB_backbone_2644
# prot_name:4FOB_backbone
# frame_name:_2644
# Final frame_name:2644
# full_name:4FOB_backbone_2305
# prot_name:4FOB_backbone
# frame_name:_2305
# Final frame_name:2305
# full_name:4FOB_backbone_1471
# prot_name:4FOB_backbone
# frame_name:_1471
# Final frame_name:1471
# full_name:4FOB_backbone_759
# prot_name:4FOB_backbone
# frame_name:_759
# Final frame_name:759
# full_name:4FOB_backbone_607
# prot_name:4FOB_backbone
# frame_name:_607
# Final frame_name:607
# full_name:4FOB_backbone_439
# prot_name:4FOB_backbone
# frame_name:_439
# Final frame_name:439
# full_name:4FOB_backbone_2569
# prot_name:4FOB_backbone
# frame_name:_2569
# Final frame_name:2569
# full_name:4FOB_backbone_2420
# prot_name:4FOB_backbone
# frame_name:_2420
# Final frame_name:2420
# full_name:4FOB_backbone_1683
# prot_name:4FOB_backbone
# frame_name:_1683
# Final frame_name:1683
# full_name:4FOB_backbone_328
# prot_name:4FOB_backbone
# frame_name:_328
# Final frame_name:328
# full_name:4FOB_backbone_707
# prot_name:4FOB_backbone
# frame_name:_707
# Final frame_name:707
# full_name:4FOB_backbone_2738
# prot_name:4FOB_backbone
# frame_name:_2738
# Final frame_name:2738
# full_name:4FOB_backbone_1336
# prot_name:4FOB_backbone
# frame_name:_1336
# Final frame_name:1336
# full_name:4FOB_backbone_2375
# prot_name:4FOB_backbone
# frame_name:_2375
# Final frame_name:2375
# full_name:4FOB_backbone_708
# prot_name:4FOB_backbone
# frame_name:_708
# Final frame_name:708
# full_name:4FOB_backbone_1337
# prot_name:4FOB_backbone
# frame_name:_1337
# Final frame_name:1337
# full_name:4FOB_backbone_2378
# prot_name:4FOB_backbone
# frame_name:_2378
# Final frame_name:2378
# full_name:4FOB_backbone_2314
# prot_name:4FOB_backbone
# frame_name:_2314
# Final frame_name:2314
# full_name:4FOB_backbone_1036
# prot_name:4FOB_backbone
# frame_name:_1036
# Final frame_name:1036
# full_name:4FOB_backbone_74
# prot_name:4FOB_backbone
# frame_name:_74
# Final frame_name:74
# full_name:4FOB_backbone_19
# prot_name:4FOB_backbone
# frame_name:_19
# Final frame_name:19
# full_name:4FOB_backbone_231
# prot_name:4FOB_backbone
# frame_name:_231
# Final frame_name:231
# full_name:4FOB_backbone_612
# prot_name:4FOB_backbone
# frame_name:_612
# Final frame_name:612
# full_name:4FOB_backbone_2039
# prot_name:4FOB_backbone
# frame_name:_2039
# Final frame_name:2039
# full_name:4FOB_backbone_1992
# prot_name:4FOB_backbone
# frame_name:_1992
# Final frame_name:1992
# full_name:4FOB_backbone_2413
# prot_name:4FOB_backbone
# frame_name:_2413
# Final frame_name:2413
# full_name:4FOB_backbone_2084
# prot_name:4FOB_backbone
# frame_name:_2084
# Final frame_name:2084
# full_name:4FOB_backbone_2194
# prot_name:4FOB_backbone
# frame_name:_2194
# Final frame_name:2194
# full_name:4FOB_backbone_686
# prot_name:4FOB_backbone
# frame_name:_686
# Final frame_name:686
# full_name:4FOB_backbone_928
# prot_name:4FOB_backbone
# frame_name:_928
# Final frame_name:928
# full_name:4FOB_backbone_426
# prot_name:4FOB_backbone
# frame_name:_426
# Final frame_name:426
# full_name:4FOB_backbone_1185
# prot_name:4FOB_backbone
# frame_name:_1185
# Final frame_name:1185
# full_name:4FOB_backbone_364
# prot_name:4FOB_backbone
# frame_name:_364
# Final frame_name:364
# full_name:4FOB_backbone_1301
# prot_name:4FOB_backbone
# frame_name:_1301
# Final frame_name:1301
# full_name:4FOB_backbone_1292
# prot_name:4FOB_backbone
# frame_name:_1292
# Final frame_name:1292
# full_name:4FOB_backbone_2449
# prot_name:4FOB_backbone
# frame_name:_2449
# Final frame_name:2449
# full_name:4FOB_backbone_1781
# prot_name:4FOB_backbone
# frame_name:_1781
# Final frame_name:1781
# full_name:4FOB_backbone_635
# prot_name:4FOB_backbone
# frame_name:_635
# Final frame_name:635
# full_name:4FOB_backbone_2105
# prot_name:4FOB_backbone
# frame_name:_2105
# Final frame_name:2105
# full_name:4FOB_backbone_2029
# prot_name:4FOB_backbone
# frame_name:_2029
# Final frame_name:2029
# full_name:4FOB_backbone_2101
# prot_name:4FOB_backbone
# frame_name:_2101
# Final frame_name:2101
# full_name:4FOB_backbone_920
# prot_name:4FOB_backbone
# frame_name:_920
# Final frame_name:920
# full_name:4FOB_backbone_743
# prot_name:4FOB_backbone
# frame_name:_743
# Final frame_name:743
# full_name:4FOB_backbone_1951
# prot_name:4FOB_backbone
# frame_name:_1951
# Final frame_name:1951
# full_name:4FOB_backbone_2584
# prot_name:4FOB_backbone
# frame_name:_2584
# Final frame_name:2584
# full_name:4FOB_backbone_30
# prot_name:4FOB_backbone
# frame_name:_30
# Final frame_name:30
# full_name:4FOB_backbone_1536
# prot_name:4FOB_backbone
# frame_name:_1536
# Final frame_name:1536
# full_name:4FOB_backbone_2529
# prot_name:4FOB_backbone
# frame_name:_2529
# Final frame_name:2529
# full_name:4FOB_backbone_657
# prot_name:4FOB_backbone
# frame_name:_657
# Final frame_name:657
# full_name:4FOB_backbone_2701
# prot_name:4FOB_backbone
# frame_name:_2701
# Final frame_name:2701
# full_name:4FOB_backbone_1809
# prot_name:4FOB_backbone
# frame_name:_1809
# Final frame_name:1809
# full_name:4FOB_backbone_2254
# prot_name:4FOB_backbone
# frame_name:_2254
# Final frame_name:2254
# full_name:4FOB_backbone_412
# prot_name:4FOB_backbone
# frame_name:_412
# Final frame_name:412
# full_name:4FOB_backbone_996
# prot_name:4FOB_backbone
# frame_name:_996
# Final frame_name:996
# full_name:4FOB_backbone_208
# prot_name:4FOB_backbone
# frame_name:_208
# Final frame_name:208
# full_name:4FOB_backbone_1184
# prot_name:4FOB_backbone
# frame_name:_1184
# Final frame_name:1184
# full_name:4FOB_backbone_2286
# prot_name:4FOB_backbone
# frame_name:_2286
# Final frame_name:2286
# full_name:4FOB_backbone_56
# prot_name:4FOB_backbone
# frame_name:_56
# Final frame_name:56
# full_name:4FOB_backbone_1902
# prot_name:4FOB_backbone
# frame_name:_1902
# Final frame_name:1902
# full_name:4FOB_backbone_1005
# prot_name:4FOB_backbone
# frame_name:_1005
# Final frame_name:1005
# full_name:4FOB_backbone_1059
# prot_name:4FOB_backbone
# frame_name:_1059
# Final frame_name:1059
# full_name:4FOB_backbone_2633
# prot_name:4FOB_backbone
# frame_name:_2633
# Final frame_name:2633
# full_name:4FOB_backbone_1118
# prot_name:4FOB_backbone
# frame_name:_1118
# Final frame_name:1118
# full_name:4FOB_backbone_2097
# prot_name:4FOB_backbone
# frame_name:_2097
# Final frame_name:2097
# full_name:4FOB_backbone_1718
# prot_name:4FOB_backbone
# frame_name:_1718
# Final frame_name:1718
# full_name:4FOB_backbone_2389
# prot_name:4FOB_backbone
# frame_name:_2389
# Final frame_name:2389
# full_name:4FOB_backbone_2052
# prot_name:4FOB_backbone
# frame_name:_2052
# Final frame_name:2052
# full_name:4FOB_backbone_2155
# prot_name:4FOB_backbone
# frame_name:_2155
# Final frame_name:2155
# full_name:4FOB_backbone_689
# prot_name:4FOB_backbone
# frame_name:_689
# Final frame_name:689
# full_name:4FOB_backbone_729
# prot_name:4FOB_backbone
# frame_name:_729
# Final frame_name:729
# full_name:4FOB_backbone_1461
# prot_name:4FOB_backbone
# frame_name:_1461
# Final frame_name:1461
# full_name:4FOB_backbone_2598
# prot_name:4FOB_backbone
# frame_name:_2598
# Final frame_name:2598
# full_name:4FOB_backbone_493
# prot_name:4FOB_backbone
# frame_name:_493
# Final frame_name:493
# full_name:4FOB_backbone_1454
# prot_name:4FOB_backbone
# frame_name:_1454
# Final frame_name:1454
# full_name:4FOB_backbone_2467
# prot_name:4FOB_backbone
# frame_name:_2467
# Final frame_name:2467
# full_name:4FOB_backbone_1604
# prot_name:4FOB_backbone
# frame_name:_1604
# Final frame_name:1604
# full_name:4FOB_backbone_1339
# prot_name:4FOB_backbone
# frame_name:_1339
# Final frame_name:1339
# full_name:4FOB_backbone_2370
# prot_name:4FOB_backbone
# frame_name:_2370
# Final frame_name:2370
# full_name:4FOB_backbone_1540
# prot_name:4FOB_backbone
# frame_name:_1540
# Final frame_name:1540
# full_name:4FOB_backbone_2457
# prot_name:4FOB_backbone
# frame_name:_2457
# Final frame_name:2457
# full_name:4FOB_backbone_377
# prot_name:4FOB_backbone
# frame_name:_377
# Final frame_name:377
# full_name:4FOB_backbone_344
# prot_name:4FOB_backbone
# frame_name:_344
# Final frame_name:344
# full_name:4FOB_backbone_1077
# prot_name:4FOB_backbone
# frame_name:_1077
# Final frame_name:1077
# full_name:4FOB_backbone_1089
# prot_name:4FOB_backbone
# frame_name:_1089
# Final frame_name:1089
# full_name:4FOB_backbone_388
# prot_name:4FOB_backbone
# frame_name:_388
# Final frame_name:388
# full_name:4FOB_backbone_696
# prot_name:4FOB_backbone
# frame_name:_696
# Final frame_name:696
# full_name:4FOB_backbone_448
# prot_name:4FOB_backbone
# frame_name:_448
# Final frame_name:448
# full_name:4FOB_backbone_1249
# prot_name:4FOB_backbone
# frame_name:_1249
# Final frame_name:1249
# full_name:4FOB_backbone_1136
# prot_name:4FOB_backbone
# frame_name:_1136
# Final frame_name:1136
# full_name:4FOB_backbone_1259
# prot_name:4FOB_backbone
# frame_name:_1259
# Final frame_name:1259
# full_name:4FOB_backbone_1231
# prot_name:4FOB_backbone
# frame_name:_1231
# Final frame_name:1231
# full_name:4FOB_backbone_1166
# prot_name:4FOB_backbone
# frame_name:_1166
# Final frame_name:1166
# full_name:4FOB_backbone_1462
# prot_name:4FOB_backbone
# frame_name:_1462
# Final frame_name:1462
# full_name:4FOB_backbone_1736
# prot_name:4FOB_backbone
# frame_name:_1736
# Final frame_name:1736
# full_name:4FOB_backbone_179
# prot_name:4FOB_backbone
# frame_name:_179
# Final frame_name:179
# full_name:4FOB_backbone_1866
# prot_name:4FOB_backbone
# frame_name:_1866
# Final frame_name:1866
# full_name:4FOB_backbone_2115
# prot_name:4FOB_backbone
# frame_name:_2115
# Final frame_name:2115
# full_name:4FOB_backbone_2472
# prot_name:4FOB_backbone
# frame_name:_2472
# Final frame_name:2472
# full_name:4FOB_backbone_1063
# prot_name:4FOB_backbone
# frame_name:_1063
# Final frame_name:1063
# full_name:4FOB_backbone_1834
# prot_name:4FOB_backbone
# frame_name:_1834
# Final frame_name:1834
# full_name:4FOB_backbone_347
# prot_name:4FOB_backbone
# frame_name:_347
# Final frame_name:347
# full_name:4FOB_backbone_2152
# prot_name:4FOB_backbone
# frame_name:_2152
# Final frame_name:2152
# full_name:4FOB_backbone_1590
# prot_name:4FOB_backbone
# frame_name:_1590
# Final frame_name:1590
# full_name:4FOB_backbone_2263
# prot_name:4FOB_backbone
# frame_name:_2263
# Final frame_name:2263
# full_name:4FOB_backbone_850
# prot_name:4FOB_backbone
# frame_name:_850
# Final frame_name:850
# full_name:4FOB_backbone_2575
# prot_name:4FOB_backbone
# frame_name:_2575
# Final frame_name:2575
# full_name:4FOB_backbone_660
# prot_name:4FOB_backbone
# frame_name:_660
# Final frame_name:660
# full_name:4FOB_backbone_2343
# prot_name:4FOB_backbone
# frame_name:_2343
# Final frame_name:2343
# full_name:4FOB_backbone_1592
# prot_name:4FOB_backbone
# frame_name:_1592
# Final frame_name:1592
# full_name:4FOB_backbone_2083
# prot_name:4FOB_backbone
# frame_name:_2083
# Final frame_name:2083
# full_name:4FOB_backbone_2411
# prot_name:4FOB_backbone
# frame_name:_2411
# Final frame_name:2411
# full_name:4FOB_backbone_829
# prot_name:4FOB_backbone
# frame_name:_829
# Final frame_name:829
# full_name:4FOB_backbone_2224
# prot_name:4FOB_backbone
# frame_name:_2224
# Final frame_name:2224
# full_name:4FOB_backbone_2248
# prot_name:4FOB_backbone
# frame_name:_2248
# Final frame_name:2248
# full_name:4FOB_backbone_2160
# prot_name:4FOB_backbone
# frame_name:_2160
# Final frame_name:2160
# full_name:4FOB_backbone_762
# prot_name:4FOB_backbone
# frame_name:_762
# Final frame_name:762
# full_name:4FOB_backbone_505
# prot_name:4FOB_backbone
# frame_name:_505
# Final frame_name:505
# full_name:4FOB_backbone_1943
# prot_name:4FOB_backbone
# frame_name:_1943
# Final frame_name:1943
# full_name:4FOB_backbone_1778
# prot_name:4FOB_backbone
# frame_name:_1778
# Final frame_name:1778
# full_name:4FOB_backbone_1152
# prot_name:4FOB_backbone
# frame_name:_1152
# Final frame_name:1152
# full_name:4FOB_backbone_888
# prot_name:4FOB_backbone
# frame_name:_888
# Final frame_name:888
# full_name:4FOB_backbone_1235
# prot_name:4FOB_backbone
# frame_name:_1235
# Final frame_name:1235
# full_name:4FOB_backbone_392
# prot_name:4FOB_backbone
# frame_name:_392
# Final frame_name:392
# full_name:4FOB_backbone_1516
# prot_name:4FOB_backbone
# frame_name:_1516
# Final frame_name:1516
# full_name:4FOB_backbone_257
# prot_name:4FOB_backbone
# frame_name:_257
# Final frame_name:257
# full_name:4FOB_backbone_1708
# prot_name:4FOB_backbone
# frame_name:_1708
# Final frame_name:1708
# full_name:4FOB_backbone_1073
# prot_name:4FOB_backbone
# frame_name:_1073
# Final frame_name:1073
# full_name:4FOB_backbone_2578
# prot_name:4FOB_backbone
# frame_name:_2578
# Final frame_name:2578
# full_name:4FOB_backbone_1727
# prot_name:4FOB_backbone
# frame_name:_1727
# Final frame_name:1727
# full_name:4FOB_backbone_2566
# prot_name:4FOB_backbone
# frame_name:_2566
# Final frame_name:2566
# full_name:4FOB_backbone_2613
# prot_name:4FOB_backbone
# frame_name:_2613
# Final frame_name:2613
# full_name:4FOB_backbone_1626
# prot_name:4FOB_backbone
# frame_name:_1626
# Final frame_name:1626
# full_name:4FOB_backbone_2639
# prot_name:4FOB_backbone
# frame_name:_2639
# Final frame_name:2639
# full_name:4FOB_backbone_437
# prot_name:4FOB_backbone
# frame_name:_437
# Final frame_name:437
# full_name:4FOB_backbone_2707
# prot_name:4FOB_backbone
# frame_name:_2707
# Final frame_name:2707
# full_name:4FOB_backbone_1867
# prot_name:4FOB_backbone
# frame_name:_1867
# Final frame_name:1867
# full_name:4FOB_backbone_1678
# prot_name:4FOB_backbone
# frame_name:_1678
# Final frame_name:1678
